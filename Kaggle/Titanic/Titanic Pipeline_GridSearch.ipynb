# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

#import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
#    for filename in filenames:
#        print(os.path.join(dirname, filename))
#
# Any results you write to the current directory are saved as output.

# %%
# Load libraries
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
# get titanic & test csv files as a DataFrame
X_orig = pd.read_csv("Titanic_train.csv")
X_test_orig = pd.read_csv("Titanic_test.csv")

# make a copy
X = X_orig.copy()
X_test = X_test_orig.copy()

# separate target from predictors
y = X.Survived
X.drop(['Survived'], axis=1, inplace=True)

# %%
X.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# remove columns
X.drop(['PassengerId', 'Name',
       'Ticket', 'Cabin', 'Embarked'], axis=1, inplace=True)
X_test.drop(['PassengerId', 'Name',
       'Ticket', 'Cabin', 'Embarked'], axis=1, inplace=True)

# %%
X.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare
# 0       3    male  22.0      1      0   7.2500
# 1       1  female  38.0      1      0  71.2833
# 2       3  female  26.0      0      0   7.9250
# 3       1  female  35.0      1      0  53.1000
# 4       3    male  35.0      0      0   8.0500

# %%
# Numerical and categorical columns transformers
numeric_features = ['Age', 'Fare']
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_features = ['Sex']
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# Append classifier to preprocessing pipeline
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', RandomForestClassifier())])

# Create space of candidate learning algorithms and their hyperparameters
search_space = [{'classifier': [LogisticRegression(random_state = 0)],
                 'classifier__penalty': ['l1', 'l2'],
                 'classifier__C': np.logspace(0, 4, 10)},
                {'classifier': [RandomForestClassifier(random_state = 0)],
                 'classifier__n_estimators': range(10, 1000, 50),
                 'classifier__max_depth': range(1,10,1),
                }]

# %%
# Create grid search 
grid = GridSearchCV(clf, search_space, cv=5, verbose=0)

# %%
# Fit grid search
best_model = grid.fit(X, y)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
results = pd.DataFrame(grid.cv_results_)
results
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.034588      0.007911         0.013597        0.000802
# 1         0.031190      0.002400         0.012195        0.000400
# 2         0.035988      0.006030         0.013197        0.001469
# 3         0.036588      0.006799         0.014797        0.001470
# 4         0.040186      0.004018         0.015797        0.003185
# 5         0.032191      0.000978         0.014596        0.000800
# 6         0.053184      0.007725         0.015594        0.002245
# 7         0.033392      0.001021         0.013795        0.001166
# 8         0.080572      0.011889         0.013197        0.000399
# 9         0.030800      0.001720         0.013787        0.001475
# 10        0.034389      0.002155         0.015595        0.002796
# 11        0.035788      0.003968         0.015796        0.003123
# 12        0.035988      0.006417         0.014797        0.002398
# 13        0.038589      0.004839         0.017194        0.002478
# 14        0.033591      0.004758         0.015794        0.003122
# 15        0.033789      0.004705         0.014596        0.002330
# 16        0.040187      0.004068         0.016797        0.003057
# 17        0.035990      0.004604         0.016394        0.003259
# 18        0.033790      0.001474         0.014793        0.002711
# 19        0.038191      0.005843         0.015393        0.001853
# 20        0.061178      0.007328         0.018196        0.001721
# 21        0.180543      0.019223         0.030990        0.003845
# 22        0.290909      0.014011         0.046383        0.011323
# 23        0.492044      0.075564         0.061180        0.006553
# 24        0.611217      0.051604         0.073978        0.006839
# 25        0.705430      0.012754         0.084573        0.006739
# 26        0.924982      0.190815         0.104765        0.011579
# 27        1.036467      0.043007         0.119785        0.017643
# 28        1.118392      0.024067         0.131229        0.011226
# 29        1.482124      0.251819         0.189035        0.055316
# ..             ...           ...              ...             ...
# 170       1.753780      0.081087         0.163872        0.005533
# 171       1.794223      0.057527         0.172700        0.006699
# 172       1.976001      0.048798         0.189020        0.004968
# 173       2.119049      0.069751         0.200916        0.005799
# 174       2.277449      0.042949         0.219270        0.007943
# 175       2.574028      0.156860         0.252907        0.028087
# 176       2.595728      0.065392         0.247009        0.004957
# 177       2.763572      0.053302         0.263357        0.006401
# 178       2.879041      0.026941         0.293432        0.022963
# 179       3.081064      0.114246         0.305103        0.015229
# 180       0.075377      0.008329         0.019193        0.004400
# 181       0.245250      0.015178         0.034598        0.007522
# 182       0.382902      0.007622         0.049998        0.007822
# 183       0.544854      0.008519         0.061138        0.004898
# 184       0.714167      0.029122         0.074274        0.005715
# 185       0.888139      0.029821         0.091852        0.002480
# 186       1.067140      0.024852         0.104926        0.008179
# 187       1.170005      0.012870         0.120038        0.007103
# 188       1.384009      0.027090         0.137971        0.009802
# 189       1.565318      0.061622         0.154689        0.008392
# 190       1.927939      0.127560         0.179992        0.033188
# 191       2.499643      0.483777         0.194364        0.029542
# 192       2.174961      0.491967         0.213684        0.045486
# 193       2.129192      0.226639         0.193985        0.011137
# 194       2.234814      0.045758         0.212726        0.012478
# 195       2.331816      0.102162         0.226847        0.018184
# 196       2.674245      0.149529         0.256276        0.015284
# 197       3.083942      0.583350         0.264115        0.013826
# 198       2.576333      0.357313         0.249115        0.044706
# 199       3.344435      0.099384         0.322031        0.026992
#
#                                       param_classifier param_classifier__C  \
# 0    LogisticRegression(C=10000.0, class_weight=Non...                   1
# 1    LogisticRegression(C=10000.0, class_weight=Non...                   1
# 2    LogisticRegression(C=10000.0, class_weight=Non...             2.78256
# 3    LogisticRegression(C=10000.0, class_weight=Non...             2.78256
# 4    LogisticRegression(C=10000.0, class_weight=Non...             7.74264
# 5    LogisticRegression(C=10000.0, class_weight=Non...             7.74264
# 6    LogisticRegression(C=10000.0, class_weight=Non...             21.5443
# 7    LogisticRegression(C=10000.0, class_weight=Non...             21.5443
# 8    LogisticRegression(C=10000.0, class_weight=Non...             59.9484
# 9    LogisticRegression(C=10000.0, class_weight=Non...             59.9484
# 10   LogisticRegression(C=10000.0, class_weight=Non...              166.81
# 11   LogisticRegression(C=10000.0, class_weight=Non...              166.81
# 12   LogisticRegression(C=10000.0, class_weight=Non...             464.159
# 13   LogisticRegression(C=10000.0, class_weight=Non...             464.159
# 14   LogisticRegression(C=10000.0, class_weight=Non...             1291.55
# 15   LogisticRegression(C=10000.0, class_weight=Non...             1291.55
# 16   LogisticRegression(C=10000.0, class_weight=Non...             3593.81
# 17   LogisticRegression(C=10000.0, class_weight=Non...             3593.81
# 18   LogisticRegression(C=10000.0, class_weight=Non...               10000
# 19   LogisticRegression(C=10000.0, class_weight=Non...               10000
# 20   (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 21   (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 22   (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 23   (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 24   (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 25   (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 26   (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 27   (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 28   (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 29   (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# ..                                                 ...                 ...
# 170  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 171  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 172  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 173  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 174  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 175  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 176  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 177  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 178  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 179  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 180  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 181  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 182  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 183  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 184  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 185  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 186  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 187  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 188  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 189  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 190  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 191  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 192  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 193  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 194  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 195  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 196  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 197  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 198  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
# 199  (DecisionTreeClassifier(class_weight=None, cri...                 NaN
#
#     param_classifier__penalty param_classifier__max_depth  \
# 0                          l1                         NaN
# 1                          l2                         NaN
# 2                          l1                         NaN
# 3                          l2                         NaN
# 4                          l1                         NaN
# 5                          l2                         NaN
# 6                          l1                         NaN
# 7                          l2                         NaN
# 8                          l1                         NaN
# 9                          l2                         NaN
# 10                         l1                         NaN
# 11                         l2                         NaN
# 12                         l1                         NaN
# 13                         l2                         NaN
# 14                         l1                         NaN
# 15                         l2                         NaN
# 16                         l1                         NaN
# 17                         l2                         NaN
# 18                         l1                         NaN
# 19                         l2                         NaN
# 20                        NaN                           1
# 21                        NaN                           1
# 22                        NaN                           1
# 23                        NaN                           1
# 24                        NaN                           1
# 25                        NaN                           1
# 26                        NaN                           1
# 27                        NaN                           1
# 28                        NaN                           1
# 29                        NaN                           1
# ..                        ...                         ...
# 170                       NaN                           8
# 171                       NaN                           8
# 172                       NaN                           8
# 173                       NaN                           8
# 174                       NaN                           8
# 175                       NaN                           8
# 176                       NaN                           8
# 177                       NaN                           8
# 178                       NaN                           8
# 179                       NaN                           8
# 180                       NaN                           9
# 181                       NaN                           9
# 182                       NaN                           9
# 183                       NaN                           9
# 184                       NaN                           9
# 185                       NaN                           9
# 186                       NaN                           9
# 187                       NaN                           9
# 188                       NaN                           9
# 189                       NaN                           9
# 190                       NaN                           9
# 191                       NaN                           9
# 192                       NaN                           9
# 193                       NaN                           9
# 194                       NaN                           9
# 195                       NaN                           9
# 196                       NaN                           9
# 197                       NaN                           9
# 198                       NaN                           9
# 199                       NaN                           9
#
#     param_classifier__n_estimators  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
# 19                             NaN
# 20                              10
# 21                              60
# 22                             110
# 23                             160
# 24                             210
# 25                             260
# 26                             310
# 27                             360
# 28                             410
# 29                             460
# ..                             ...
# 170                            510
# 171                            560
# 172                            610
# 173                            660
# 174                            710
# 175                            760
# 176                            810
# 177                            860
# 178                            910
# 179                            960
# 180                             10
# 181                             60
# 182                            110
# 183                            160
# 184                            210
# 185                            260
# 186                            310
# 187                            360
# 188                            410
# 189                            460
# 190                            510
# 191                            560
# 192                            610
# 193                            660
# 194                            710
# 195                            760
# 196                            810
# 197                            860
# 198                            910
# 199                            960
#
#                                                 params  split0_test_score  \
# 0    {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 1    {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 2    {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 3    {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 4    {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 5    {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 6    {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 7    {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 8    {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 9    {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 10   {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 11   {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 12   {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 13   {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 14   {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 15   {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 16   {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 17   {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 18   {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 19   {'classifier': LogisticRegression(C=10000.0, c...           0.793296
# 20   {'classifier': (DecisionTreeClassifier(class_w...           0.804469
# 21   {'classifier': (DecisionTreeClassifier(class_w...           0.804469
# 22   {'classifier': (DecisionTreeClassifier(class_w...           0.804469
# 23   {'classifier': (DecisionTreeClassifier(class_w...           0.804469
# 24   {'classifier': (DecisionTreeClassifier(class_w...           0.804469
# 25   {'classifier': (DecisionTreeClassifier(class_w...           0.804469
# 26   {'classifier': (DecisionTreeClassifier(class_w...           0.804469
# 27   {'classifier': (DecisionTreeClassifier(class_w...           0.804469
# 28   {'classifier': (DecisionTreeClassifier(class_w...           0.804469
# 29   {'classifier': (DecisionTreeClassifier(class_w...           0.804469
# ..                                                 ...                ...
# 170  {'classifier': (DecisionTreeClassifier(class_w...           0.804469
#